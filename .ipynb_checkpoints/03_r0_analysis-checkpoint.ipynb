# %% [markdown]
# # R0 Analysis of COVID-19
# 22 March 2020
#
# Cecilia García López de Munain

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import os, sys
import matplotlib.pyplot as plt
import pickle
from datetime import timedelta
import datetime

# %% [markdown]
# ## Parameters

# %%
sys.path.append('./')

# %%
PATH_ROOT_INPUT_DATA = 'data\\input'
PATH_ROOT_INTERIM_DATA = 'data\\interim'
INTERIM_DATA_NAME_COVID = 'covid_19_data_cum.pkl'
INTERIM_DATA_NAME_GOVM = 'government_measures.csv'

# %% [markdown]
# ## Import Data

# %% [markdown]
# COVID Data

# %%
covid19_data = pickle.load(open(os.path.join(PATH_ROOT_INTERIM_DATA,INTERIM_DATA_NAME_COVID), "rb" ))

# %%
covid19_data.head()
# Out:
#             Day  Month  Year  NewConfCases  NewDeaths       CountryExp GeoId  \
# DateRep
# 2019-12-31   31     12  2019             0          0  North_Macedonia    MK
# 2019-12-31   31     12  2019             0          0       Azerbaijan    AZ
# 2019-12-31   31     12  2019             0          0        Singapore    SG
# 2019-12-31   31     12  2019             0          0           Brazil    BR
# 2019-12-31   31     12  2019             0          0           Kuwait    KW
#
#             NewConfCases_cum  NewDeaths_cum   Population  Population Density
# DateRep
# 2019-12-31                 0              0          NaN                 NaN
# 2019-12-31                 0              0    9942334.0          120.265320
# 2019-12-31                 0              0    5638676.0         7952.998418
# 2019-12-31                 0              0  209469333.0           25.061716
# 2019-12-31                 0              0    4137309.0          232.172222

# %%
covid19_data.columns
# Out:
# Index(['Day', 'Month', 'Year', 'NewConfCases', 'NewDeaths', 'CountryExp',
#        'GeoId', 'NewConfCases_cum', 'NewDeaths_cum', 'Population',
#        'Population Density'],
#       dtype='object')

# %%
# Not studying conveyance Japan so dropping it 
covid19_data = covid19_data.loc[covid19_data['CountryExp'] != 'Cases on an international conveyance Japan',:]

# %%
list(covid19_data['CountryExp'].sort_values().unique())
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua_and_Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia_and_Herzegovina',
#  'Brazil',
#  'Brunei_Darussalam',
#  'Bulgaria',
#  'Burkina_Faso',
#  'CANADA',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape_Verde',
#  'Cases_on_an_international_conveyance_Japan',
#  'Cayman_Islands',
#  'Central_African_Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo',
#  'Costa_Rica',
#  'Cote_dIvoire',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech_Republic',
#  'Democratic_Republic_of_the_Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominican_Republic',
#  'Ecuador',
#  'Egypt',
#  'El_Salvador',
#  'Equatorial_Guinea',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Faroe_Islands',
#  'Fiji',
#  'Finland',
#  'France',
#  'French_Polynesia',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Guam',
#  'Guatemala',
#  'Guernsey',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Holy_See',
#  'Honduras',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Isle_of_Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jersey',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Latvia',
#  'Lebanon',
#  'Liberia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malaysia',
#  'Maldives',
#  'Malta',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'Netherlands_Antilles',
#  'New_Caledonia',
#  'New_Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North_Macedonia',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Palestine',
#  'Panama',
#  'Papua_New_Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saint_Lucia',
#  'Saint_Vincent_and_the_Grenadines',
#  'San_Marino',
#  'Saudi_Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Somalia',
#  'South_Africa',
#  'South_Korea',
#  'Spain',
#  'Sri_Lanka',
#  'Sudan',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Thailand',
#  'Timor_Leste',
#  'Togo',
#  'Trinidad_and_Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United_Arab_Emirates',
#  'United_Kingdom',
#  'United_Republic_of_Tanzania',
#  'United_States_of_America',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela',
#  'Vietnam',
#  'Zambia',
#  'Zimbabwe']

# %% [markdown]
# Government Measures Data

# %%
gov_measures = pd.read_csv(os.path.join(PATH_ROOT_INPUT_DATA, INTERIM_DATA_NAME_GOVM))

# %%
gov_measures.head()
# Out:
#   CountryExp                   Government Measure  DaysFromFirst
# 0      Spain                Alerta Epidemiológica              6
# 1      Spain  Supervisión de ingreso de pasajeros             36
# 2      Spain                   Cierre de escuelas             41
# 3      Spain              Licencias y home office             41
# 4      Spain               Cierre de espectáculos             42

# %% [markdown]
# ## Compute moving averages

# %%
def compute_growth_3days(df):
    '''This function computes the proportion in which the total confirmed cases increase each 3 days'''
    
    df.loc[:,'Growth3Days'] = np.nan
    df.sort_values(['CountryExp','DateRep'], inplace=True)
    df.loc[:,'Growth3Days'] = df.loc[:,'NewConfCases_cum'] / df.shift(3).loc[:,'NewConfCases_cum'].where(
        cond=(df.loc[:,'CountryExp'] == df.shift(3).loc[:,'CountryExp']) & (df.shift(3).loc[:,'NewConfCases_cum'] > 0)
    )
    df.sort_index(inplace=True)
    return df

# %%
compute_growth_3days(covid19_data)
# Out:
#             Day  Month  Year  NewConfCases  NewDeaths   CountryExp GeoId  \
# DateRep
# 2019-12-31   31     12  2019             0          0  Afghanistan    AF
# 2019-12-31   31     12  2019             0          0       Greece    EL
# 2019-12-31   31     12  2019             0          0      Germany    DE
# 2019-12-31   31     12  2019             0          0      Georgia    GE
# 2019-12-31   31     12  2019             0          0       France    FR
# ...         ...    ...   ...           ...        ...          ...   ...
# 2020-03-22   22      3  2020            12          0    Sri_Lanka    LK
# 2020-03-22   22      3  2020            64          0      Iceland    IS
# 2020-03-22   22      3  2020            19          0      Belarus    BY
# 2020-03-22   22      3  2020             0          0      Bermuda    BM
# 2020-03-22   22      3  2020             1          0     Zimbabwe    ZW
#
#             NewConfCases_cum  NewDeaths_cum  Population  Population Density  \
# DateRep
# 2019-12-31                 0              0  37172386.0           56.937760
# 2019-12-31                 0              0  10727668.0           83.224732
# 2019-12-31                 0              0  82927922.0          237.370970
# 2019-12-31                 0              0   3731000.0           65.275202
# 2019-12-31                 0              0  66987244.0          122.338396
# ...                      ...            ...         ...                 ...
# 2020-03-22                78              0         NaN                 NaN
# 2020-03-22               473              1    353574.0            3.526923
# 2020-03-22                76              0   9485386.0           46.728800
# 2020-03-22                 2              0     63968.0         1184.592572
# 2020-03-22                 2              0  14439018.0           37.324591
#
#             Growth3Days
# DateRep
# 2019-12-31          NaN
# 2019-12-31          NaN
# 2019-12-31          NaN
# 2019-12-31          NaN
# 2019-12-31          NaN
# ...                 ...
# 2020-03-22     1.857143
# 2020-03-22     1.892000
# 2020-03-22     1.652174
# 2020-03-22          NaN
# 2020-03-22          NaN
#
# [6188 rows x 12 columns]

# %%
# Sort value for moving averages
covid19_data = covid19_data.reset_index().sort_values(['CountryExp','DateRep'], ascending=True)

# %%
# Compute previous growth average
def calc_pre_rolling_mean(df):
    '''This function computes de difference in days between the flags of max prop increment and max increment'''
    
    df.loc[:,'previous_growth_3d'] = np.nan
    for country in df.loc[:,'CountryExp'].unique():
        data = df.loc[df.loc[:,'CountryExp']==country,:]
        df.loc[df.loc[:,'CountryExp']==country,'previous_growth_3d'] = data.loc[:,'Growth3Days'].expanding(1).mean()

# %%
calc_pre_rolling_mean(covid19_data)

# %%
# Compute previous growth average
def calc_fwd_rolling_mean(df):
    '''This function computes de difference in days between the flags of max prop increment and max increment'''
    
    df.loc[:,'forward_growth_3d'] = np.nan
    for country in df.loc[:,'CountryExp'].unique():
        data = df.loc[df.loc[:,'CountryExp']==country,:]
        df.loc[df.loc[:,'CountryExp']==country,'forward_growth_3d'] = data.sort_values(['CountryExp','DateRep'], ascending=False)['Growth3Days'].expanding(1).mean()
        df.loc[df.loc[:,'CountryExp']==country,'forward_growth_3d'] = np.where(df.loc[df.loc[:,'CountryExp']==country,'Growth3Days'].notnull(), df.loc[df.loc[:,'CountryExp']==country,'forward_growth_3d'], np.nan)

# %%
calc_fwd_rolling_mean(covid19_data)

# %%
covid19_data.set_index('DateRep', inplace=True)

# %%
covid19_data.loc[covid19_data.loc[:,'CountryExp']=='Afghanistan',:]
# Out:
#             Day  Month  Year  NewConfCases  NewDeaths   CountryExp GeoId  \
# DateRep
# 2019-12-31   31     12  2019             0          0  Afghanistan    AF
# 2020-01-01    1      1  2020             0          0  Afghanistan    AF
# 2020-01-02    2      1  2020             0          0  Afghanistan    AF
# 2020-01-03    3      1  2020             0          0  Afghanistan    AF
# 2020-01-04    4      1  2020             0          0  Afghanistan    AF
# ...         ...    ...   ...           ...        ...          ...   ...
# 2020-03-18   18      3  2020             1          0  Afghanistan    AF
# 2020-03-19   19      3  2020             0          0  Afghanistan    AF
# 2020-03-20   20      3  2020             0          0  Afghanistan    AF
# 2020-03-21   21      3  2020             2          0  Afghanistan    AF
# 2020-03-22   22      3  2020             0          0  Afghanistan    AF
#
#             NewConfCases_cum  NewDeaths_cum  Population  Population Density  \
# DateRep
# 2019-12-31                 0              0  37172386.0            56.93776
# 2020-01-01                 0              0  37172386.0            56.93776
# 2020-01-02                 0              0  37172386.0            56.93776
# 2020-01-03                 0              0  37172386.0            56.93776
# 2020-01-04                 0              0  37172386.0            56.93776
# ...                      ...            ...         ...                 ...
# 2020-03-18                22              0  37172386.0            56.93776
# 2020-03-19                22              0  37172386.0            56.93776
# 2020-03-20                22              0  37172386.0            56.93776
# 2020-03-21                24              0  37172386.0            56.93776
# 2020-03-22                24              0  37172386.0            56.93776
#
#             Growth3Days  previous_growth_3d  forward_growth_3d
# DateRep
# 2019-12-31          NaN                 NaN                NaN
# 2020-01-01          NaN                 NaN                NaN
# 2020-01-02          NaN                 NaN                NaN
# 2020-01-03          NaN                 NaN                NaN
# 2020-01-04          NaN                 NaN                NaN
# ...                 ...                 ...                ...
# 2020-03-18     2.200000            3.420000           1.360887
# 2020-03-19     1.375000            3.234091           1.151109
# 2020-03-20     1.047619            3.051885           1.076479
# 2020-03-21     1.090909            2.901041           1.090909
# 2020-03-22     1.090909            2.771746           1.090909
#
# [73 rows x 14 columns]

# %% [markdown]
# ## Join datasets

# %%
# Filter countries in Government Measures
covid19_data_filtered = covid19_data.loc[covid19_data.loc[:,'CountryExp'].isin(list(gov_measures.loc[:,'CountryExp'].unique()))]

covid19_data_filtered = covid19_data_filtered.loc[covid19_data_filtered.loc[:,'NewConfCases']>0,'CountryExp'].reset_index().groupby('CountryExp').min()

# %%
covid19_data_filtered = covid19_data_filtered.merge(gov_measures, on='CountryExp', how='left')

# %%
covid19_data.head()
# Out:
#             Day  Month  Year  NewConfCases  NewDeaths   CountryExp GeoId  \
# DateRep
# 2019-12-31   31     12  2019             0          0  Afghanistan    AF
# 2020-01-01    1      1  2020             0          0  Afghanistan    AF
# 2020-01-02    2      1  2020             0          0  Afghanistan    AF
# 2020-01-03    3      1  2020             0          0  Afghanistan    AF
# 2020-01-04    4      1  2020             0          0  Afghanistan    AF
#
#             NewConfCases_cum  NewDeaths_cum  Population  Population Density  \
# DateRep
# 2019-12-31                 0              0  37172386.0            56.93776
# 2020-01-01                 0              0  37172386.0            56.93776
# 2020-01-02                 0              0  37172386.0            56.93776
# 2020-01-03                 0              0  37172386.0            56.93776
# 2020-01-04                 0              0  37172386.0            56.93776
#
#             Growth3Days  previous_growth_3d  forward_growth_3d
# DateRep
# 2019-12-31          NaN                 NaN                NaN
# 2020-01-01          NaN                 NaN                NaN
# 2020-01-02          NaN                 NaN                NaN
# 2020-01-03          NaN                 NaN                NaN
# 2020-01-04          NaN                 NaN                NaN

# %%
# covid19_data_filtered = covid19_data_filtered.merge(gov_measures, on='CountryExp', how='left')
# covid19_data_filtered.loc[:,'DateRep'] 

covid19_data_filtered.loc[:,'DayOfGovM'] = covid19_data_filtered.loc[:,'DateRep'] + pd.to_timedelta(covid19_data_filtered.loc[:,'DaysFromFirst'], unit='D')

# %%
covid19_data_filtered.head(20)
# Out:
#    CountryExp    DateRep                        Government Measure  \
# 0       China 2019-12-31              Recomendación de aislamiento
# 1       China 2019-12-31      Limitaciones drásticas al transporte
# 2       China 2019-12-31                    Cierre de espectáculos
# 3       China 2019-12-31                        Cierre de escuelas
# 4       China 2019-12-31             Bloqueo de ciudades afectadas
# 5       China 2019-12-31  Apertura de clases en algunas provincias
# 6      France 2020-01-25                    Cierre de espectáculos
# 7      France 2020-01-25              Recomendación de aislamiento
# 8      France 2020-01-25                   Licencias y home office
# 9      France 2020-01-25                        Cierre de escuelas
# 10      Italy 2020-01-31              Recomendación de aislamiento
# 11      Italy 2020-01-31             Bloqueo de ciudades afectadas
# 12      Italy 2020-01-31                        Cierre de escuelas
# 13      Italy 2020-01-31                    Cierre de espectáculos
# 14      Italy 2020-01-31                       Cierre de fronteras
# 15      Italy 2020-01-31      Limitaciones drásticas al transporte
# 16      Italy 2020-01-31                   Licencias y home office
# 17      Spain 2020-02-01                     Alerta Epidemiológica
# 18      Spain 2020-02-01       Supervisión de ingreso de pasajeros
# 19      Spain 2020-02-01                        Cierre de escuelas
#
#     DaysFromFirst  DayOfGovM
# 0              23 2020-01-23
# 1              24 2020-01-24
# 2              24 2020-01-24
# 3              27 2020-01-27
# 4              34 2020-02-03
# 5              72 2020-03-12
# 6              43 2020-03-08
# 7              51 2020-03-16
# 8              51 2020-03-16
# 9              51 2020-03-16
# 10              1 2020-02-01
# 11             23 2020-02-23
# 12             35 2020-03-06
# 13             35 2020-03-06
# 14             40 2020-03-11
# 15             40 2020-03-11
# 16             45 2020-03-16
# 17              6 2020-02-07
# 18             36 2020-03-08
# 19             41 2020-03-13

# %%
covid19_data_withgovm = pd.merge(covid19_data.reset_index(), covid19_data_filtered.loc[:,['CountryExp','Government Measure','DayOfGovM','DaysFromFirst']], left_on=['CountryExp','DateRep'], right_on=['CountryExp','DayOfGovM'], how='left').set_index('DateRep')

# %%
covid19_data_withgovm.head()
# Out:
#             Day  Month  Year  NewConfCases  NewDeaths   CountryExp GeoId  \
# DateRep
# 2019-12-31   31     12  2019             0          0  Afghanistan    AF
# 2020-01-01    1      1  2020             0          0  Afghanistan    AF
# 2020-01-02    2      1  2020             0          0  Afghanistan    AF
# 2020-01-03    3      1  2020             0          0  Afghanistan    AF
# 2020-01-04    4      1  2020             0          0  Afghanistan    AF
#
#             NewConfCases_cum  NewDeaths_cum  Population  Population Density  \
# DateRep
# 2019-12-31                 0              0  37172386.0            56.93776
# 2020-01-01                 0              0  37172386.0            56.93776
# 2020-01-02                 0              0  37172386.0            56.93776
# 2020-01-03                 0              0  37172386.0            56.93776
# 2020-01-04                 0              0  37172386.0            56.93776
#
#             Growth3Days  previous_growth_3d  forward_growth_3d  \
# DateRep
# 2019-12-31          NaN                 NaN                NaN
# 2020-01-01          NaN                 NaN                NaN
# 2020-01-02          NaN                 NaN                NaN
# 2020-01-03          NaN                 NaN                NaN
# 2020-01-04          NaN                 NaN                NaN
#
#            Government Measure DayOfGovM  DaysFromFirst
# DateRep
# 2019-12-31                NaN       NaT            NaN
# 2020-01-01                NaN       NaT            NaN
# 2020-01-02                NaN       NaT            NaN
# 2020-01-03                NaN       NaT            NaN
# 2020-01-04                NaN       NaT            NaN

# %%
covid19_data_withgovm = covid19_data_withgovm.loc[covid19_data_withgovm.loc[:,'CountryExp'].isin(covid19_data_filtered.loc[:,'CountryExp']),:]

# %% [markdown]
# ## Analyse mesures

# %%
gov_measures.head(30)
# Out:
#    CountryExp                        Government Measure  DaysFromFirst
# 0       Spain                     Alerta Epidemiológica              6
# 1       Spain       Supervisión de ingreso de pasajeros             36
# 2       Spain                        Cierre de escuelas             41
# 3       Spain                   Licencias y home office             41
# 4       Spain                    Cierre de espectáculos             42
# 5       Spain       Restricciones al transporte público             46
# 6       Spain      Limitaciones drásticas al transporte             48
# 7       Italy              Recomendación de aislamiento              1
# 8       Italy             Bloqueo de ciudades afectadas             23
# 9       Italy                        Cierre de escuelas             35
# 10      Italy                    Cierre de espectáculos             35
# 11      Italy                       Cierre de fronteras             40
# 12      Italy      Limitaciones drásticas al transporte             40
# 13      Italy                   Licencias y home office             45
# 14     France                    Cierre de espectáculos             43
# 15     France              Recomendación de aislamiento             51
# 16     France                   Licencias y home office             51
# 17     France                        Cierre de escuelas             51
# 18      China              Recomendación de aislamiento             23
# 19      China      Limitaciones drásticas al transporte             24
# 20      China                    Cierre de espectáculos             24
# 21      China                        Cierre de escuelas             27
# 22      China             Bloqueo de ciudades afectadas             34
# 23      China  Apertura de clases en algunas provincias             72

# %%
list_of_measures = gov_measures.loc[:,'Government Measure'].unique()
list_of_countries =  covid19_data_withgovm.loc[:,'CountryExp'].unique()
print(list_of_measures)
print(list_of_countries)
# Out:
# ['Alerta Epidemiológica' 'Supervisión de ingreso de pasajeros'
#  'Cierre de escuelas' 'Licencias y home office' 'Cierre de espectáculos'
#  'Restricciones al transporte público'
#  'Limitaciones drásticas al transporte' 'Recomendación de aislamiento'
#  'Bloqueo de ciudades afectadas' 'Cierre de fronteras'
#  'Apertura de clases en algunas provincias']
# ['China' 'France' 'Italy' 'Spain']

# %%
[(x,y) for x in ['Cierre de escuelas', 'Cierre de espectáculos', 'Limitaciones drásticas al transporte'] for y in list_of_countries]
# Out:
# [('Cierre de escuelas', 'China'),
#  ('Cierre de escuelas', 'France'),
#  ('Cierre de escuelas', 'Italy'),
#  ('Cierre de escuelas', 'Spain'),
#  ('Cierre de espectáculos', 'China'),
#  ('Cierre de espectáculos', 'France'),
#  ('Cierre de espectáculos', 'Italy'),
#  ('Cierre de espectáculos', 'Spain'),
#  ('Limitaciones drásticas al transporte', 'China'),
#  ('Limitaciones drásticas al transporte', 'France'),
#  ('Limitaciones drásticas al transporte', 'Italy'),
#  ('Limitaciones drásticas al transporte', 'Spain')]

# %%
measures_countries =  [(x,y) for x in ['Cierre de escuelas',  'Cierre de espectáculos', 'Limitaciones drásticas al transporte'] for y in list_of_countries]

# %% [markdown]
# ### Some Plotting

# %%
for measure, country in measures_countries:
    
    event = covid19_data_withgovm.loc[(covid19_data_withgovm.loc[:,'Government Measure']==measure) & (covid19_data_withgovm.loc[:,'CountryExp']==country),'NewConfCases_cum']
    if len(event)>0:

        fig, ax1 = plt.subplots()

        ax1.plot(covid19_data_withgovm.loc[covid19_data_withgovm.loc[:,'CountryExp']==country,'NewConfCases'])

        ax2 = ax1.twinx()

        ax2.plot(covid19_data_withgovm.loc[covid19_data_withgovm.loc[:,'CountryExp']==country,'NewConfCases_cum'])

        print(measure, 'en ', country,' :', event.index.values[0], 'con ', event.values[0], 'casos confirmados.')

        plt.axvline(x=event.index, linewidth=2, color='r') 
        plt.axhline(y=event.values, linewidth=2, color='r') 

        plt.title(country + '-' + measure)
# Out:
# c:\users\c.lopez.de.munain\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_matplotlib\converter.py:102: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Cierre de escuelas en  China  : 2020-01-27T00:00:00.000000000 con  2775 casos confirmados.
# Cierre de escuelas en  France  : 2020-03-16T00:00:00.000000000 con  5423 casos confirmados.
# Cierre de escuelas en  Italy  : 2020-03-06T00:00:00.000000000 con  3858 casos confirmados.
# Cierre de escuelas en  Spain  : 2020-03-13T00:00:00.000000000 con  3004 casos confirmados.
# Cierre de espectáculos en  China  : 2020-01-24T00:00:00.000000000 con  882 casos confirmados.
# Cierre de espectáculos en  France  : 2020-03-08T00:00:00.000000000 con  716 casos confirmados.
# Cierre de espectáculos en  Italy  : 2020-03-06T00:00:00.000000000 con  3858 casos confirmados.
# Cierre de espectáculos en  Spain  : 2020-03-14T00:00:00.000000000 con  4231 casos confirmados.
# Limitaciones drásticas al transporte en  China  : 2020-01-24T00:00:00.000000000 con  882 casos confirmados.
# Limitaciones drásticas al transporte en  Italy  : 2020-03-11T00:00:00.000000000 con  10149 casos confirmados.
# Limitaciones drásticas al transporte en  Spain  : 2020-03-20T00:00:00.000000000 con  17147 casos confirmados.

# %% [markdown]
# ## Determine the effect on the exponential

# %%
covid19_data_withgovm.head()
# Out:
#             Day  Month  Year  NewConfCases  NewDeaths CountryExp GeoId  \
# DateRep
# 2019-12-31   31     12  2019            27          0      China    CN
# 2020-01-01    1      1  2020             0          0      China    CN
# 2020-01-02    2      1  2020             0          0      China    CN
# 2020-01-03    3      1  2020            17          0      China    CN
# 2020-01-04    4      1  2020             0          0      China    CN
#
#             NewConfCases_cum  NewDeaths_cum    Population  Population Density  \
# DateRep
# 2019-12-31                27              0  1.392730e+09          148.348833
# 2020-01-01                27              0  1.392730e+09          148.348833
# 2020-01-02                27              0  1.392730e+09          148.348833
# 2020-01-03                44              0  1.392730e+09          148.348833
# 2020-01-04                44              0  1.392730e+09          148.348833
#
#             Growth3Days  previous_growth_3d  forward_growth_3d  \
# DateRep
# 2019-12-31          NaN                 NaN                NaN
# 2020-01-01          NaN                 NaN                NaN
# 2020-01-02          NaN                 NaN                NaN
# 2020-01-03      1.62963             1.62963           1.490825
# 2020-01-04      1.62963             1.62963           1.489068
#
#            Government Measure DayOfGovM  DaysFromFirst
# DateRep
# 2019-12-31                NaN       NaT            NaN
# 2020-01-01                NaN       NaT            NaN
# 2020-01-02                NaN       NaT            NaN
# 2020-01-03                NaN       NaT            NaN
# 2020-01-04                NaN       NaT            NaN

# %% [markdown]
# ### Compute effects of gov measures

# %%
covid19_data_withgovm.loc[covid19_data_withgovm.loc[:,'CountryExp']=='China',:]
# Out:
#             Day  Month  Year  NewConfCases  NewDeaths CountryExp GeoId  \
# DateRep
# 2019-12-31   31     12  2019            27          0      China    CN
# 2020-01-01    1      1  2020             0          0      China    CN
# 2020-01-02    2      1  2020             0          0      China    CN
# 2020-01-03    3      1  2020            17          0      China    CN
# 2020-01-04    4      1  2020             0          0      China    CN
# ...         ...    ...   ...           ...        ...        ...   ...
# 2020-03-18   18      3  2020            33         16      China    CN
# 2020-03-19   19      3  2020            75          8      China    CN
# 2020-03-20   20      3  2020            99          4      China    CN
# 2020-03-21   21      3  2020            79          7      China    CN
# 2020-03-22   22      3  2020            83          6      China    CN
#
#             NewConfCases_cum  NewDeaths_cum    Population  Population Density  \
# DateRep
# 2019-12-31                27              0  1.392730e+09          148.348833
# 2020-01-01                27              0  1.392730e+09          148.348833
# 2020-01-02                27              0  1.392730e+09          148.348833
# 2020-01-03                44              0  1.392730e+09          148.348833
# 2020-01-04                44              0  1.392730e+09          148.348833
# ...                      ...            ...           ...                 ...
# 2020-03-18             81163           3242  1.392730e+09          148.348833
# 2020-03-19             81238           3250  1.392730e+09          148.348833
# 2020-03-20             81337           3254  1.392730e+09          148.348833
# 2020-03-21             81416           3261  1.392730e+09          148.348833
# 2020-03-22             81499           3267  1.392730e+09          148.348833
#
#             Growth3Days  previous_growth_3d  forward_growth_3d  \
# DateRep
# 2019-12-31          NaN                 NaN                NaN
# 2020-01-01          NaN                 NaN                NaN
# 2020-01-02          NaN                 NaN                NaN
# 2020-01-03     1.629630            1.629630           1.490825
# 2020-01-04     1.629630            1.629630           1.489068
# ...                 ...                 ...                ...
# 2020-03-18     1.002074            1.516506           1.002729
# 2020-03-19     1.002691            1.509833           1.002893
# 2020-03-20     1.002551            1.503329           1.002960
# 2020-03-21     1.003117            1.496998           1.003165
# 2020-03-22     1.003213            1.490825           1.003213
#
#            Government Measure DayOfGovM  DaysFromFirst
# DateRep
# 2019-12-31                NaN       NaT            NaN
# 2020-01-01                NaN       NaT            NaN
# 2020-01-02                NaN       NaT            NaN
# 2020-01-03                NaN       NaT            NaN
# 2020-01-04                NaN       NaT            NaN
# ...                       ...       ...            ...
# 2020-03-18                NaN       NaT            NaN
# 2020-03-19                NaN       NaT            NaN
# 2020-03-20                NaN       NaT            NaN
# 2020-03-21                NaN       NaT            NaN
# 2020-03-22                NaN       NaT            NaN
#
# [84 rows x 17 columns]

# %%
# Consolidate effects of government measures on growth
measures_effect = covid19_data_withgovm.loc[~covid19_data_withgovm.loc[:,'Government Measure'].isna(),['CountryExp','Government Measure','DaysFromFirst','Growth3Days','previous_growth_3d','forward_growth_3d']]
measures_effect.rename(columns={'Growth3Days':'actual_value_growth'}, inplace=True)

# %%
# Compute impact
measures_effect.loc[:,'growth_effect'] = measures_effect.loc[:,'forward_growth_3d'] / measures_effect.loc[:,'previous_growth_3d']

# %%
measures_effect
# Out:
#            CountryExp                        Government Measure  \
# DateRep
# 2020-01-23      China              Recomendación de aislamiento
# 2020-01-24      China      Limitaciones drásticas al transporte
# 2020-01-24      China                    Cierre de espectáculos
# 2020-01-27      China                        Cierre de escuelas
# 2020-02-03      China             Bloqueo de ciudades afectadas
# 2020-03-12      China  Apertura de clases en algunas provincias
# 2020-03-08     France                    Cierre de espectáculos
# 2020-03-16     France              Recomendación de aislamiento
# 2020-03-16     France                   Licencias y home office
# 2020-03-16     France                        Cierre de escuelas
# 2020-02-01      Italy              Recomendación de aislamiento
# 2020-02-23      Italy             Bloqueo de ciudades afectadas
# 2020-03-06      Italy                        Cierre de escuelas
# 2020-03-06      Italy                    Cierre de espectáculos
# 2020-03-11      Italy                       Cierre de fronteras
# 2020-03-11      Italy      Limitaciones drásticas al transporte
# 2020-03-16      Italy                   Licencias y home office
# 2020-02-07      Spain                     Alerta Epidemiológica
# 2020-03-08      Spain       Supervisión de ingreso de pasajeros
# 2020-03-13      Spain                        Cierre de escuelas
# 2020-03-13      Spain                   Licencias y home office
# 2020-03-14      Spain                    Cierre de espectáculos
# 2020-03-18      Spain       Restricciones al transporte público
# 2020-03-20      Spain      Limitaciones drásticas al transporte
#
#             DaysFromFirst  actual_value_growth  previous_growth_3d  \
# DateRep
# 2020-01-23           23.0             2.651064            1.754877
# 2020-01-24           24.0             2.284974            1.778972
# 2020-01-24           24.0             2.284974            1.778972
# 2020-01-27           27.0             3.146259            1.919595
# 2020-02-03           34.0             1.771773            2.030110
# 2020-03-12           72.0             1.000903            1.560673
# 2020-03-08           43.0             2.512281            1.678363
# 2020-03-16           51.0             1.885605            1.760052
# 2020-03-16           51.0             1.885605            1.760052
# 2020-03-16           51.0             1.885605            1.760052
# 2020-02-01            1.0                  NaN                 NaN
# 2020-02-23           23.0            26.333333            2.428571
# 2020-03-06           35.0             2.102452            4.085072
# 2020-03-06           35.0             2.102452            4.085072
# 2020-03-11           40.0             1.725140            3.794210
# 2020-03-11           40.0             1.725140            3.794210
# 2020-03-16           45.0             1.586713            3.541130
# 2020-02-07            6.0             1.000000            1.000000
# 2020-03-08           36.0             2.150000            2.116977
# 2020-03-13           41.0             2.495017            2.240849
# 2020-03-13           41.0             2.495017            2.240849
# 2020-03-14           42.0             2.581452            2.249364
# 2020-03-18           46.0             1.942986            2.258160
# 2020-03-20           48.0             1.865629            2.238996
#
#             forward_growth_3d  growth_effect
# DateRep
# 2020-01-23           1.417744       0.807888
# 2020-01-24           1.396841       0.785195
# 2020-01-24           1.396841       0.785195
# 2020-01-27           1.328972       0.692319
# 2020-02-03           1.144373       0.563700
# 2020-03-12           1.001801       0.641903
# 2020-03-08           2.001894       1.192766
# 2020-03-16           1.710292       0.971728
# 2020-03-16           1.710292       0.971728
# 2020-03-16           1.710292       0.971728
# 2020-02-01                NaN            NaN
# 2020-02-23           4.721028       1.943953
# 2020-03-06           1.698328       0.415740
# 2020-03-06           1.698328       0.415740
# 2020-03-11           1.593472       0.419975
# 2020-03-11           1.593472       0.419975
# 2020-03-16           1.556374       0.439514
# 2020-02-07           2.302190       2.302190
# 2020-03-08           2.451421       1.157982
# 2020-03-13           2.170045       0.968403
# 2020-03-13           2.170045       0.968403
# 2020-03-14           2.133937       0.948685
# 2020-03-18           1.836494       0.813270
# 2020-03-20           1.823454       0.814407

# %%
# European countries
european_effects = measures_effect.loc[measures_effect.loc[:,'CountryExp'].isin(['France','Italy','Spain']),:].groupby('Government Measure')['DaysFromFirst','actual_value_growth','growth_effect'].mean()
european_effects
# Out:
#                                       DaysFromFirst  actual_value_growth  \
# Government Measure
# Alerta Epidemiológica                      6.000000             1.000000
# Bloqueo de ciudades afectadas             23.000000            26.333333
# Cierre de escuelas                        42.333333             2.161025
# Cierre de espectáculos                    40.000000             2.398728
# Cierre de fronteras                       40.000000             1.725140
# Licencias y home office                   45.666667             1.989112
# Limitaciones drásticas al transporte      44.000000             1.795385
# Recomendación de aislamiento              26.000000             1.885605
# Restricciones al transporte público       46.000000             1.942986
# Supervisión de ingreso de pasajeros       36.000000             2.150000
#
#                                       growth_effect
# Government Measure
# Alerta Epidemiológica                      2.302190
# Bloqueo de ciudades afectadas              1.943953
# Cierre de escuelas                         0.785290
# Cierre de espectáculos                     0.852397
# Cierre de fronteras                        0.419975
# Licencias y home office                    0.793215
# Limitaciones drásticas al transporte       0.617191
# Recomendación de aislamiento               0.971728
# Restricciones al transporte público        0.813270
# Supervisión de ingreso de pasajeros        1.157982

# %%
# China
china_effects = measures_effect.loc[measures_effect.loc[:,'CountryExp'].isin(['China']),:].groupby('Government Measure')['DaysFromFirst','actual_value_growth','growth_effect'].mean()
china_effects
# Out:
#                                           DaysFromFirst  actual_value_growth  \
# Government Measure
# Apertura de clases en algunas provincias           72.0             1.000903
# Bloqueo de ciudades afectadas                      34.0             1.771773
# Cierre de escuelas                                 27.0             3.146259
# Cierre de espectáculos                             24.0             2.284974
# Limitaciones drásticas al transporte               24.0             2.284974
# Recomendación de aislamiento                       23.0             2.651064
#
#                                           growth_effect
# Government Measure
# Apertura de clases en algunas provincias       0.641903
# Bloqueo de ciudades afectadas                  0.563700
# Cierre de escuelas                             0.692319
# Cierre de espectáculos                         0.785195
# Limitaciones drásticas al transporte           0.785195
# Recomendación de aislamiento                   0.807888

# %%
df_effects = european_effects.merge(china_effects,left_index=True,right_index=True,how='outer',suffixes=('_eu', '_ch'))

df_effects.loc[:,'effect_diff'] = (df_effects.loc[:,'growth_effect_eu'] - df_effects.loc[:,'growth_effect_ch']) / df_effects.loc[:,'growth_effect_eu']

# %%
df_effects.to_csv('C:\\Users\\c.lopez.de.munain\\Documents\\covid_19\\data\\govmeasures_effect.csv')

# %%
df_effects.round(2).dropna()
# Out:
#                                       DaysFromFirst_eu  \
# Government Measure
# Bloqueo de ciudades afectadas                    23.00
# Cierre de escuelas                               42.33
# Cierre de espectáculos                           40.00
# Limitaciones drásticas al transporte             44.00
# Recomendación de aislamiento                     26.00
#
#                                       actual_value_growth_eu  \
# Government Measure
# Bloqueo de ciudades afectadas                          26.33
# Cierre de escuelas                                      2.16
# Cierre de espectáculos                                  2.40
# Limitaciones drásticas al transporte                    1.80
# Recomendación de aislamiento                            1.89
#
#                                       growth_effect_eu  DaysFromFirst_ch  \
# Government Measure
# Bloqueo de ciudades afectadas                     1.94              34.0
# Cierre de escuelas                                0.79              27.0
# Cierre de espectáculos                            0.85              24.0
# Limitaciones drásticas al transporte              0.62              24.0
# Recomendación de aislamiento                      0.97              23.0
#
#                                       actual_value_growth_ch  \
# Government Measure
# Bloqueo de ciudades afectadas                           1.77
# Cierre de escuelas                                      3.15
# Cierre de espectáculos                                  2.28
# Limitaciones drásticas al transporte                    2.28
# Recomendación de aislamiento                            2.65
#
#                                       growth_effect_ch  effect_diff
# Government Measure
# Bloqueo de ciudades afectadas                     0.56         0.71
# Cierre de escuelas                                0.69         0.12
# Cierre de espectáculos                            0.79         0.08
# Limitaciones drásticas al transporte              0.79        -0.27
# Recomendación de aislamiento                      0.81         0.17
